# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
src = 'imputed_csv/gene_predicted_rest_median_imputed_no_outliers.csv'
df = pd.read_csv(src, index_col=0)

# %%
cols = df.columns

mri_shape_cols = [col for col in cols if '_shape_' in col]

# %%
sns.pairplot(df[mri_shape_cols + ['RelapseFreeSurvival (outcome)']], hue="RelapseFreeSurvival (outcome)")
