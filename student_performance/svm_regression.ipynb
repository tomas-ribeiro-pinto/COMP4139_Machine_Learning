# %%
from ucimlrepo import fetch_ucirepo 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import scipy
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

# fetch dataset 
student_performance = fetch_ucirepo(id=320) 
  
# data (as pandas dataframes) 
X = student_performance.data.features 
y = student_performance.data.targets

# %%
for i, column in enumerate(X.columns):
    print(f"{i} Column '{column}' has data type: {X[column].dtype}")
# Out:
# 0 Column 'school' has data type: object
# 1 Column 'sex' has data type: object
# 2 Column 'age' has data type: int64
# 3 Column 'address' has data type: object
# 4 Column 'famsize' has data type: object
# 5 Column 'Pstatus' has data type: object
# 6 Column 'Medu' has data type: int64
# 7 Column 'Fedu' has data type: int64
# 8 Column 'Mjob' has data type: object
# 9 Column 'Fjob' has data type: object
# 10 Column 'reason' has data type: object
# 11 Column 'guardian' has data type: object
# 12 Column 'traveltime' has data type: int64
# 13 Column 'studytime' has data type: int64
# 14 Column 'failures' has data type: int64
# 15 Column 'schoolsup' has data type: object
# 16 Column 'famsup' has data type: object
# 17 Column 'paid' has data type: object
# 18 Column 'activities' has data type: object
# 19 Column 'nursery' has data type: object
# 20 Column 'higher' has data type: object
# 21 Column 'internet' has data type: object
# 22 Column 'romantic' has data type: object
# 23 Column 'famrel' has data type: int64
# 24 Column 'freetime' has data type: int64
# 25 Column 'goout' has data type: int64
# 26 Column 'Dalc' has data type: int64
# 27 Column 'Walc' has data type: int64
# 28 Column 'health' has data type: int64
# 29 Column 'absences' has data type: int64

# %%
## data processing
data_mean = X.iloc[:, [2,6,7,12,13,14,23,24,25,26,27,28,29]]
data_mean.plot(kind='box', subplots=True, layout=(8,4), sharex=False,
sharey=False, fontsize=12, figsize=(15,20))

data_mean.head()

scaler = StandardScaler()
Xs = scaler.fit_transform(data_mean)

# Print features normalised (Xs)
fig,ax=plt.subplots(1,figsize=(15,10))
sns.boxplot(data=Xs,ax=ax)
# Out:
# <Axes: >
